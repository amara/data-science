# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

file_name = "my_iris.xlsx"

# %%
df = pd.read_excel(file_name)

# Dropping Unnamed Column 
# Dropping target column since data is redundant
df.drop([df.columns[0], df.columns[-1]], axis= 1, inplace= True) 
df
# Out:
#      sepal depth  sepal diameter  petal depth  petal diameter  sepal length  \
# 0            NaN             NaN          NaN             NaN          10.2
# 1            4.9             3.0          1.4             0.2           9.8
# 2            4.7             3.2          NaN             NaN           9.4
# 3            4.6             NaN          1.5             NaN           9.2
# 4            NaN             3.6          NaN             NaN          10.0
# ..           ...             ...          ...             ...           ...
# 145          6.7             3.0          5.2             2.3          13.4
# 146          6.3             2.5          5.0             1.9          12.6
# 147          6.5             3.0          5.2             2.0          13.0
# 148          6.2             3.4          5.4             2.3          12.4
# 149          5.9             3.0          5.1             1.8          11.8
#
#      sepal width  petal length  petal width
# ...

# %%
pca = PCA(n_components= 2)
df_naFill = df.fillna(df.mean())
components = pca.fit_transform(df_naFill)

comp1 = components[:,0]
comp2 = components[:,1]
df_pca = pd.DataFrame([comp1, comp2]).transpose()
Skew = 3 * (df_pca.mean() - df_pca.median()) / df_pca.std()
Skew
print(Skew)

plt.scatter(comp1, comp2)
# Out:
# 0   -0.873762
# 1    0.069475
# dtype: float64

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\yousu\AppData\Local\Temp\ipykernel_2468\2001914525.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_ab564_row0_col0, #T_ab564_row0_col4, #T_ab564_row1_col1, #T_ab564_row2_col2, #T_ab564_row2_col6, #T_ab564_row3_col3, #T_ab564_row4_col0, #T_ab564_row4_col4, #T_ab564_row5_col5, #T_ab564_row6_col2, #T_ab564_row6_col6, #T_ab564_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ab564_row0_col1, #T_ab564_row5_col4 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_ab564_row0_col2, #T_ab564_row4_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_ab564_row0_col3, #T_ab564_row4_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_ab564_row0_col5 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_ab564_row0_col6, #T_ab564_row4_col6 {
#   background-color: #cb3e38;
# ...

# %%
df.isna().sum()
# Out:
# sepal depth       20
# sepal diameter    20
# petal depth       20
# petal diameter    50
# sepal length       0
# sepal width        0
# petal length       0
# petal width        0
# dtype: int64

# %%
df_min = df.fillna(df.min())
df_median = df.fillna(df.median())
df_avg = df.fillna(df.mean())
df_max = df.fillna(df.max())

# %% [markdown]
# Minimum Values

# %%
df_min.head()
# Out:
#    sepal depth  sepal diameter  petal depth  petal diameter  sepal length  \
# 0          4.3             2.0          1.1             0.1          10.2
# 1          4.9             3.0          1.4             0.2           9.8
# 2          4.7             3.2          1.1             0.1           9.4
# 3          4.6             2.0          1.5             0.1           9.2
# 4          4.3             3.6          1.1             0.1          10.0
#
#    sepal width  petal length  petal width
# 0         -7.0           5.6         -0.8
# 1         -6.0           5.6         -0.8
# 2         -6.4           5.2         -0.8
# 3         -6.2           6.0         -0.8
# 4         -7.2           5.6         -0.8

# %%
corr = df_min.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\yousu\AppData\Local\Temp\ipykernel_2468\2956440192.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_01bd1_row0_col0, #T_01bd1_row1_col1, #T_01bd1_row2_col2, #T_01bd1_row2_col6, #T_01bd1_row3_col3, #T_01bd1_row4_col4, #T_01bd1_row5_col5, #T_01bd1_row6_col2, #T_01bd1_row6_col6, #T_01bd1_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_01bd1_row0_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_01bd1_row0_col2, #T_01bd1_row0_col6 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_01bd1_row0_col3 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_01bd1_row0_col4, #T_01bd1_row2_col4, #T_01bd1_row4_col0, #T_01bd1_row6_col4 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_01bd1_row0_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_01bd1_row0_col7 {
# ...

# %% [markdown]
# Average Values

# %%
df_avg.head()
# Out:
#    sepal depth  sepal diameter  petal depth  petal diameter  sepal length  \
# 0     5.901538        3.005385     4.115385           1.453          10.2
# 1     4.900000        3.000000     1.400000           0.200           9.8
# 2     4.700000        3.200000     4.115385           1.453           9.4
# 3     4.600000        3.005385     1.500000           1.453           9.2
# 4     5.901538        3.600000     4.115385           1.453          10.0
#
#    sepal width  petal length  petal width
# 0         -7.0           5.6         -0.8
# 1         -6.0           5.6         -0.8
# 2         -6.4           5.2         -0.8
# 3         -6.2           6.0         -0.8
# 4         -7.2           5.6         -0.8

# %%
corr = df_avg.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\yousu\AppData\Local\Temp\ipykernel_2468\1263959297.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_394d7_row0_col0, #T_394d7_row1_col1, #T_394d7_row2_col2, #T_394d7_row3_col3, #T_394d7_row4_col4, #T_394d7_row5_col5, #T_394d7_row6_col6, #T_394d7_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_394d7_row0_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_394d7_row0_col2, #T_394d7_row3_col2, #T_394d7_row6_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_394d7_row0_col3, #T_394d7_row3_col0 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_394d7_row0_col4 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_394d7_row0_col5, #T_394d7_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_394d7_row0_col6 {
#   background-color: #d75445;
# ...

# %% [markdown]
# Median Values

# %%
df_median.head()
# Out:
#    sepal depth  sepal diameter  petal depth  petal diameter  sepal length  \
# 0         5.85             3.0          4.5             1.5          10.2
# 1         4.90             3.0          1.4             0.2           9.8
# 2         4.70             3.2          4.5             1.5           9.4
# 3         4.60             3.0          1.5             1.5           9.2
# 4         5.85             3.6          4.5             1.5          10.0
#
#    sepal width  petal length  petal width
# 0         -7.0           5.6         -0.8
# 1         -6.0           5.6         -0.8
# 2         -6.4           5.2         -0.8
# 3         -6.2           6.0         -0.8
# 4         -7.2           5.6         -0.8

# %%
corr = df_median.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\yousu\AppData\Local\Temp\ipykernel_2468\2277636353.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_bb20e_row0_col0, #T_bb20e_row1_col1, #T_bb20e_row2_col2, #T_bb20e_row3_col3, #T_bb20e_row4_col4, #T_bb20e_row5_col5, #T_bb20e_row6_col6, #T_bb20e_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bb20e_row0_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_bb20e_row0_col2 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_bb20e_row0_col3, #T_bb20e_row6_col3 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_bb20e_row0_col4, #T_bb20e_row4_col0 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_bb20e_row0_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_bb20e_row0_col6, #T_bb20e_row2_col6 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# Max Values

# %%
df_max.head()
# Out:
#    sepal depth  sepal diameter  petal depth  petal diameter  sepal length  \
# 0          7.9             4.1          6.9             2.5          10.2
# 1          4.9             3.0          1.4             0.2           9.8
# 2          4.7             3.2          6.9             2.5           9.4
# 3          4.6             4.1          1.5             2.5           9.2
# 4          7.9             3.6          6.9             2.5          10.0
#
#    sepal width  petal length  petal width
# 0         -7.0           5.6         -0.8
# 1         -6.0           5.6         -0.8
# 2         -6.4           5.2         -0.8
# 3         -6.2           6.0         -0.8
# 4         -7.2           5.6         -0.8

# %%
corr = df_max.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\yousu\AppData\Local\Temp\ipykernel_2468\2217536210.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_8f469_row0_col0, #T_8f469_row1_col1, #T_8f469_row2_col2, #T_8f469_row3_col3, #T_8f469_row4_col4, #T_8f469_row5_col5, #T_8f469_row6_col6, #T_8f469_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8f469_row0_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_8f469_row0_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_8f469_row0_col3, #T_8f469_row3_col4, #T_8f469_row6_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_8f469_row0_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_8f469_row0_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_8f469_row0_col6, #T_8f469_row3_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# ...

# %%
Skew = 3 * (df.mean() - df.median()) / df.std()
Skew
# Out:
# sepal depth       0.185150
# sepal diameter    0.039398
# petal depth      -0.711724
# petal diameter   -0.205804
# sepal length      0.156992
# sepal width      -0.373621
# petal length     -1.005429
# petal width       0.398343
# dtype: float64

# %% [markdown]
# A skewness value greater than 1 or less than -1 indicates a highly skewed distribution. A value between 0.5 and 1 or -0.5 and -1 is moderately skewed. A value between -0.5 and 0.5 indicates that the distribution is fairly symmetrical.
#
# Using Min or Max filling method has a high chance of filling the values with outliers so we wont use that method
#
# Since the data is not highly skewed, we can use the mean for the best results using the average value for filling NA rows.

# %%
# Saving the AVG filled dataframe:
df_avg.to_excel("mean_filled.xlsx")

# %% [markdown]
# Checking correaltion matrix

# %%
corr = df_avg.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# C:\Users\yousu\AppData\Local\Temp\ipykernel_2468\3533349581.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(3)
# <style type="text/css">
# #T_cf20d_row0_col0, #T_cf20d_row1_col1, #T_cf20d_row2_col2, #T_cf20d_row3_col3, #T_cf20d_row4_col4, #T_cf20d_row5_col5, #T_cf20d_row6_col6, #T_cf20d_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cf20d_row0_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_cf20d_row0_col2, #T_cf20d_row3_col2, #T_cf20d_row6_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_cf20d_row0_col3, #T_cf20d_row3_col0 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_cf20d_row0_col4 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_cf20d_row0_col5, #T_cf20d_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_cf20d_row0_col6 {
#   background-color: #d75445;
# ...

# %% [markdown]
# petal width: has strong negative correlation (correlation < -0.7)
#
# and
#
# sepal depth, petal length, petal depth: has strong positive correlation with the data (correlation > 0.7)
#
# all rows will be removed

# %%
df_avg.drop(["sepal depth", "petal width", "petal depth", "petal length", "sepal width"], axis= 1, inplace= True)

# %%
corr = df_avg.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# C:\Users\yousu\AppData\Local\Temp\ipykernel_2468\3533349581.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(3)
# <style type="text/css">
# #T_fb0f9_row0_col0, #T_fb0f9_row1_col1, #T_fb0f9_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fb0f9_row0_col1, #T_fb0f9_row0_col2, #T_fb0f9_row1_col0, #T_fb0f9_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fb0f9_row1_col2, #T_fb0f9_row2_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# </style>
# <table id="T_fb0f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb0f9_level0_col0" class="col_heading level0 col0" >sepal diameter</th>
#       <th id="T_fb0f9_level0_col1" class="col_heading level0 col1" >petal diameter</th>
#       <th id="T_fb0f9_level0_col2" class="col_heading level0 col2" >sepal length</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# Removing all high correlation columns leaves us with the final data set containing
#
# Sepal Diamater, Petel Diameter, and Sepal Length

# %%
df_avg.head()
# Out:
#    sepal diameter  petal diameter  sepal length
# 0        3.005385           1.453          10.2
# 1        3.000000           0.200           9.8
# 2        3.200000           1.453           9.4
# 3        3.005385           1.453           9.2
# 4        3.600000           1.453          10.0

# %%
df_avg.describe()
# Out:
#        sepal diameter  petal diameter  sepal length
# count      150.000000      150.000000    150.000000
# mean         3.005385        1.453000     11.686667
# std          0.381504        0.558456      1.656132
# min          2.000000        0.100000      8.600000
# 25%          2.800000        1.300000     10.200000
# 50%          3.000000        1.453000     11.600000
# 75%          3.200000        1.800000     12.800000
# max          4.100000        2.500000     15.800000

# %%
df = pd.read_excel(file_name)
df_avg["target"] = df["target"]
df_avg.to_excel("pre_processed_data.xlsx")
